# %%
from const_case import big_r_est
from gamma_case import big_r_gamma_est
from viz import *

# %%
big_r = 5 # radius of a sphere
n_sim = 1000 # number of simulations, should be divisible by n_fol

# Parameters for the R estimation function (est_box_const)
n_sim_set = [10, 100, 1000] # set of number of simulations for the R estimation function
n_rep = 30 # number of repetitions for the R estimation function

# %% [markdown]
# # Single R Case

# %%
pdf_const(big_r, n_sim)
# Out:
# AIC (Analytical): 2011.47
# AIC (Beta): 2009.33
# <module 'matplotlib.pyplot' from '/home/bees/code/lib/python3.12/site-packages/matplotlib/pyplot.py'>

# %%
big_r_est(big_r, n_sim, stats = True)
# Out:
# Estimated R: 5.014
# Difference: 0.014
# np.float64(5.014140971694851)

# %%
est_box_const(big_r, n_sim_set, n_rep)
# Out:
# <module 'matplotlib.pyplot' from '/home/bees/code/lib/python3.12/site-packages/matplotlib/pyplot.py'>

# %% [markdown]
# # Gamma R Case

# %%
theta = 2 # shape parameter
k = 2 # scale parameter
n_fol = 1000 # number of follicules

# Parameters for testing with different theta and k values
# functions viz_gamma_grid and viz_gamma_shift_grid 
k_set = [0.5, 1, 1.5]
theta_set = [1, 2, 3]

# %%
pdf_gamma(theta, k, n_fol)
# Out:
# <module 'matplotlib.pyplot' from '/home/bees/code/lib/python3.12/site-packages/matplotlib/pyplot.py'>

# %%
theta = 8

# %%
viz_gamma_shift(theta, k, n_fol, stats = True)
# Out:
# Gamma of R: shape = 8, scale = 2
# Gamma of r: shape = 4.0, scale = 3.15
# <module 'matplotlib.pyplot' from '/home/bees/code/lib/python3.12/site-packages/matplotlib/pyplot.py'>

# %%
viz_gamma_grid(theta_set, k_set, n_fol, mode = "Default")
# Out:
# /home/bees/Documents/MASTER/INTERNSHIP/spheres/modules.py:23: IntegrationWarning: The algorithm does not converge.  Roundoff error is detected
#   in the extrapolation table.  It is assumed that the requested tolerance
#   cannot be achieved, and that the returned result (if full_output = 1) is
#   the best which can be obtained.
#   integral, _ = quad(integrand, r, np.inf) # constraint: r <= R
# <module 'matplotlib.pyplot' from '/home/bees/code/lib/python3.12/site-packages/matplotlib/pyplot.py'>

# %%
viz_gamma_grid(theta_set, k_set, n_fol, mode = "Shift")
# Out:
# Shift for θ=1, k=0.5
# Gamma of R: shape = 1, scale = 0.5
# Gamma of r: shape = 0.91, scale = 0.42
#
# Shift for θ=1, k=1
# Gamma of R: shape = 1, scale = 1
# Gamma of r: shape = 0.9, scale = 0.89
#
# Shift for θ=1, k=1.5
# Gamma of R: shape = 1, scale = 1.5
# Gamma of r: shape = 0.93, scale = 1.26
#
# Shift for θ=2, k=0.5
# Gamma of R: shape = 2, scale = 0.5
# Gamma of r: shape = 1.69, scale = 0.48
#
# Shift for θ=2, k=1
# Gamma of R: shape = 2, scale = 1
# Gamma of r: shape = 1.71, scale = 0.96
#
# Shift for θ=2, k=1.5
# Gamma of R: shape = 2, scale = 1.5
# Gamma of r: shape = 1.6, scale = 1.51
#
# Shift for θ=3, k=0.5
# Gamma of R: shape = 3, scale = 0.5
# Gamma of r: shape = 2.19, scale = 0.55
#
# Shift for θ=3, k=1
# Gamma of R: shape = 3, scale = 1
# Gamma of r: shape = 2.19, scale = 1.08
#
# Shift for θ=3, k=1.5
# Gamma of R: shape = 3, scale = 1.5
# Gamma of r: shape = 2.27, scale = 1.58
# <module 'matplotlib.pyplot' from '/home/bees/code/lib/python3.12/site-packages/matplotlib/pyplot.py'>

# %%
big_r_gamma_est(theta, k, n_fol)
# Out:
# Estimated theta: 1.553
# Estimated k: 2.501
# Theta difference: -0.447
# K difference: 0.501

# %%
theta_set = [0.25, 0.5, 1, 3, 5, 10, 15, 20, 25, 30, 35, 40, 45, 50]
# for a_set we will choose scale = 2
k_set = [0.25, 0.5, 1, 3, 5, 10, 15, 20, 25, 30, 35, 40, 45, 50]
# for scale_set we will choose a = 2

# %%
params_shift(theta_set, mode = "theta")
# Out:
# <module 'matplotlib.pyplot' from '/home/bees/code/lib/python3.12/site-packages/matplotlib/pyplot.py'>

# %%
params_shift(k_set, mode = "k")
# Out:
# <module 'matplotlib.pyplot' from '/home/bees/code/lib/python3.12/site-packages/matplotlib/pyplot.py'>
